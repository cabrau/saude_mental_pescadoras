# %%
import pandas as pd
import numpy as np
from scipy.sparse import csr_matrix
import matplotlib.pyplot as plt
import altair as alt
#alt.renderers.enable('notebook')
import seaborn as sns
import re
import os, sys
import nltk
nltk.download('stopwords')
nltk.download('punkt')
from collections import Counter
from pyvis.network import Network
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from google_trans_new import google_translator
from textblob import TextBlob
import time
import string
punct = string.punctuation

# insert dir of python code in the path
module_path = os.path.abspath(os.path.join(os.pardir))
if module_path not in sys.path:
    sys.path.append(module_path)

from src.utils import *
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\lucas.cabral\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\lucas.cabral\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
module_path
# Out:
# 'C:\\Users\\lucas.cabral\\saude_mental_pescadoras'

# %% [markdown]
# # Carrega e pré-processa dados

# %%
from docx import Document
import os
import re

def get_text(filename):
    doc = Document(filename)
    fullText = []
    for para in doc.paragraphs:
        fullText.append(para.text)
    return '\n'.join(fullText)

docs_list = os.listdir('../data')
interviews = []
interviewees = []
titles = []
for doc_name in docs_list:
    if not doc_name.endswith('.docx'):
        continue
    print(doc_name, end= ' ')
    doc_path = os.path.join('..','data',doc_name)
    interview = get_text(doc_path)
    # parse interviewee
    interview = interview.replace('Marisqueiras: ', 'Marisqueira: ')
    lines_split = interview.split('Pesquisadora: ')
    interviewee = ''
    n_lines = len(re.findall(r'Marisqueira: ', interview.replace('\n',' ')))
    count = 0
    for line in lines_split:
        answer = line.split('Marisqueira: ')
        if len(answer)>1:
            interviewee += ' '.join(answer[1:])
            count+=len(answer[1:])
    print(n_lines,count)
    
    interviewees.append(interviewee)
    interviews.append(interview)
    titles.append(doc_name.replace('.docx',''))
# Out:
# Canavieiras 1.docx 16 16
# Canavieiras 2.docx 14 14
# Cumbe 1.docx 74 74
# Cumbe 2.docx 11 11
# Jardins 1.docx 53 53
# Jardins 2.docx 16 16
# Jardins 3.docx 18 18
# Jardins 4.docx 20 20

# %%
df = pd.DataFrame({'título':titles, 'entrevista':interviews, 'respostas':interviewees})
df
# Out:
#           título                                         entrevista
# 0  Canavieiras 1  Canavieiras 1 \n\nPesquisadora: Pedi sua autor...  \
# 1  Canavieiras 2  Canavieiras 2 \nPesquisadora: Só a sua tua aut...
# 2        Cumbe 1  Cumbe 1\n\nPesquisadora: Só pedir o teu aceite...
# 3        Cumbe 2  Cumbe 2 23 de jun. 15.01_.aac\nPesquisadora: S...
# 4      Jardins 1  \nJardins 1\n\nPesquisadora: Ai só confirmar c...
# 5      Jardins 2  Jardins 2 \n\nPesquisadora: Você pode só dizer...
# 6      Jardins 3  Jardins 3 \nPesquisadora: Pronto, iniciando a ...
# 7      Jardins 4  Jardins 4 \n\nPesquisadora: Sua autorização pr...
#
#                                            respostas
# 0  Assim foi. Impactou muito, né? Porque a gente ...
# 1  Eu autorizo.\n\nO primeiro foi muito ruim, né?...
# 2  Aham, concordo\n\nUhum. É, eu digo né. Que… re...
# 3  Ok, autorizo.\n\nAssim como aqui a gente veve ...
# 4  Do… de… do óleo né?\n\nDo óleo a gente… A gent...
# 5  Eu, Otacília, a carne de Albuquerque autorizo ...
# 6  Sim. Pronto.\n\nÉ assim. Primeiramente, boa ta...
# 7  Não, é claro.\n\nA gente foi atingido principa...

# %% [markdown]
# ## Processamento

# %%
# normalização e palavras chave
df['resposta normalizada'] = [preprocess(text) for text in df['respostas']]
df['palavras-chave'] = [get_keywords(text, 3) for text in df['resposta normalizada']]
# tamanho dos textos
df['número de palavras'] = [len(string.split()) for string in df['respostas']]
df['número de caracteres'] = [len(string) for string in df['respostas']]
# razão entre o número de palavras únicas e o número de palavras no texto
df['variabilidade léxica'] = [len(set(string.split()))/len(string.split()) for string in df['respostas']]
df
# Out:
#           título                                         entrevista
# 0  Canavieiras 1  Canavieiras 1 \n\nPesquisadora: Pedi sua autor...  \
# 1  Canavieiras 2  Canavieiras 2 \nPesquisadora: Só a sua tua aut...
# 2        Cumbe 1  Cumbe 1\n\nPesquisadora: Só pedir o teu aceite...
# 3        Cumbe 2  Cumbe 2 23 de jun. 15.01_.aac\nPesquisadora: S...
# 4      Jardins 1  \nJardins 1\n\nPesquisadora: Ai só confirmar c...
# 5      Jardins 2  Jardins 2 \n\nPesquisadora: Você pode só dizer...
# 6      Jardins 3  Jardins 3 \nPesquisadora: Pronto, iniciando a ...
# 7      Jardins 4  Jardins 4 \n\nPesquisadora: Sua autorização pr...
#
#                                            respostas
# 0  Assim foi. Impactou muito, né? Porque a gente ...  \
# 1  Eu autorizo.\n\nO primeiro foi muito ruim, né?...
# 2  Aham, concordo\n\nUhum. É, eu digo né. Que… re...
# 3  Ok, autorizo.\n\nAssim como aqui a gente veve ...
# 4  Do… de… do óleo né?\n\nDo óleo a gente… A gent...
# 5  Eu, Otacília, a carne de Albuquerque autorizo ...
# 6  Sim. Pronto.\n\nÉ assim. Primeiramente, boa ta...
# 7  Não, é claro.\n\nA gente foi atingido principa...
#
#                                 resposta normalizada      palavras-chave
# 0  assim impactou porque gente sobrevive marisco ...  gente, não, também  \
# 1  autorizo primeiro ruim porque coisa desconheci...  gente, não, porque
# 2  aham concordo uhum digo que… realmente derrama...     gente, não, nós
# 3  autorizo assim aqui gente veve pesca marisco e...  gente, não, também
# 4  do… de… óleo óleo gente… gente ficou… gente so...    gente, não, aqui
# 5  otacília carne albuquerque autorizo gravação t...  não, porque, gente
# 6  sim pronto assim primeiramente boa tarde porqu...  gente, não, porque
# 7  não claro gente atingido principalmente vendas...  não, gente, porque
#
#    número de palavras  número de caracteres  variabilidade léxica
# 0                 548                  3143              0.547445
# 1                 860                  4589              0.423256
# 2                6347                 34551              0.274460
# 3                1664                  9397              0.364784
# 4                2421                 12594              0.319703
# 5                 871                  4866              0.486797
# 6                1824                  9725              0.322368
# 7                1382                  7676              0.457308

# %% [markdown]
# # Termos

# %%
lyrics = ' '.join(df['resposta normalizada'])
tokens = lyrics.split()
count_tokens = Counter(tokens)
df_term = pd.DataFrame(list(count_tokens.items()), columns = ["termo","frequencia"])
df_term = df_term.sort_values(by='frequencia', ascending=False)
df_term
# Out:
#           termo  frequencia
# 3         gente         452
# 22          não         387
# 2        porque         185
# 0         assim         121
# 135         nós         118
# ...         ...         ...
# 1228     adoeça           1
# 518      coisa…           1
# 517   divulgado           1
# 1231    proximo           1
# 1962    agradou           1
#
# [1963 rows x 2 columns]

# %%
# conta a frequência dos termos
lyrics = ' '.join(df['resposta normalizada'])
tokens = lyrics.split()
count_tokens = Counter(tokens)
df_term = pd.DataFrame(list(count_tokens.items()), columns = ["termo","frequencia"])
df_term = df_term.sort_values(by='frequencia', ascending=False)

# músicas onde ocorrem
songs_by_term = []
number_of_songs_by_term = []
for term in df_term['termo']:
    songs = []
    for song, lyric in (zip(df['título'], df['resposta normalizada'])):
        if term in lyric.split():
            songs.append(song)

    number_of_songs_by_term.append(len(songs))
    songs = ' '.join(songs)
    songs_by_term.append(songs)

df_term['número de entrevistas onde o termo ocorre'] = number_of_songs_by_term
df_term['entrevistas onde o termo ocorre'] = songs_by_term

df_term.head(10)
# Out:
#           termo  frequencia  número de entrevistas onde o termo ocorre
# 3         gente         452                                          8  \
# 22          não         387                                          8
# 2        porque         185                                          8
# 0         assim         121                                          8
# 135         nós         118                                          7
# 63         aqui          90                                          8
# 52       também          90                                          8
# 12        então          78                                          7
# 186  comunidade          58                                          7
# 149     pessoas          57                                          8
#
#                        entrevistas onde o termo ocorre
# 3    Canavieiras 1 Canavieiras 2 Cumbe 1 Cumbe 2 Ja...
# 22   Canavieiras 1 Canavieiras 2 Cumbe 1 Cumbe 2 Ja...
# 2    Canavieiras 1 Canavieiras 2 Cumbe 1 Cumbe 2 Ja...
# 0    Canavieiras 1 Canavieiras 2 Cumbe 1 Cumbe 2 Ja...
# 135  Canavieiras 1 Cumbe 1 Cumbe 2 Jardins 1 Jardin...
# 63   Canavieiras 1 Canavieiras 2 Cumbe 1 Cumbe 2 Ja...
# 52   Canavieiras 1 Canavieiras 2 Cumbe 1 Cumbe 2 Ja...
# 12   Canavieiras 1 Canavieiras 2 Cumbe 1 Cumbe 2 Ja...
# 186  Canavieiras 2 Cumbe 1 Cumbe 2 Jardins 1 Jardin...
# 149  Canavieiras 1 Canavieiras 2 Cumbe 1 Cumbe 2 Ja...

# %%
# músicas onde mais ocorrem hapaxes
hapaxes = set(df_term[df_term['frequencia']==1]['termo'])
print('quantidade de hapaxes:', len(hapaxes))

hapaxes_count = []
for lyric in df['resposta normalizada']:
    tokens = set(lyric.split())
    count = len(tokens.intersection(hapaxes))
    hapaxes_count.append(count)

df['hapaxes'] = hapaxes_count
# Out:
# quantidade de hapaxes: 1033

# %% [markdown]
# # Termos mais frequentes

# %%
viz_path = os.path.join(module_path,'plots')
viz_path
# Out:
# 'C:\\Users\\lucas.cabral\\saude_mental_pescadoras\\plots'

# %%
# unigramas
texts = ' '.join(list(df['resposta normalizada']))
n_grams = (1,1)
total_bigrams = build_ngram_df(texts, ngram = n_grams, n=20)
plt.title('Unigramas mais frequentes')
plot_ngrams(total_bigrams, col='C2', orientation = 'vertical')
plt.savefig(os.path.join(viz_path,'unigramas.jpg'))

# %%
n_grams = (2,2)
total_bigrams = build_ngram_df(texts, ngram = n_grams, n=20)
plt.title('Bigramas mais frequentes')
plot_ngrams(total_bigrams, col='C1', orientation = 'vertical')
plt.savefig(os.path.join(viz_path,'bigramas.jpg'))

# %% [markdown]
# ## Adjetivos mais frequentes

# %%
import joblib
from nltk import word_tokenize
tagger_path = os.path.join(module_path,'res','POS_tagger_brill.pkl')
tagger = joblib.load(tagger_path)
phrase = 'O lindo rato roeu lindamente a roupa do rei de Roma'
tagger.tag(word_tokenize(phrase))
# Out:
# [('O', 'ART'),
#  ('lindo', 'ADJ'),
#  ('rato', 'N'),
#  ('roeu', 'V'),
#  ('lindamente', 'ADV'),
#  ('a', 'ART'),
#  ('roupa', 'N'),
#  ('do', 'KS'),
#  ('rei', 'N'),
#  ('de', 'PREP'),
#  ('Roma', 'NPROP')]

# %%
adjs = ''
for text in df['respostas']:
    tags = tagger.tag(word_tokenize(text))
    for tag in tags:
        if tag[1]=='ADJ':
            adjs += tag[0] + ' '

# %%
# adjetivos mais frequentes
n_grams = (1,1)
total_bigrams = build_ngram_df(adjs, ngram = n_grams, n=20)
plt.title('Adjetivos mais frequentes')
plot_ngrams(total_bigrams, col='C3', orientation = 'vertical')
plt.savefig(os.path.join(viz_path,'adjetivos.jpg'))

# %%
# adj + word
adj_sub = []
for text in df['respostas']:
    text = [p for p in text.split() if len(p)>3]
    text = ' '.join(text)
    for p in punct:
        text = text.replace(p,'')
        
    tags = tagger.tag(word_tokenize(text))
    for i, tag in enumerate(tags):
        if tag[1]=='ADJ':
            if i-1 > 0: #and tags[i-1][1] == 'N':
                adj_sub.append((tags[i-1][0], tag[0]))
            elif i+1 < len(tags): #and tags[i-1][1] == 'N':
                adj_sub.append((tags[i+1][0], tag[0]))
                
from collections import Counter
count = Counter(adj_sub).most_common(15)
labels = []
values = []
for c in count:
    labels.append(c[0][0] + ' ' + c[0][1])
    values.append(c[1])
    
col = 'C6' 
orientation = 'vertical'
plt.title('Bigramas com adjetivos mais frequentes')

#
if orientation == 'vertical':
    g = sns.barplot(y=labels, x=values, color = col)
    for p in g.patches:
        g.annotate(format(p.get_width(), '.0f'), (p.get_width(), 
                                                   p.get_y() + p.get_height()/2.), ha = 'center', 
                   va = 'center', xytext = (10, 0), textcoords = 'offset points')
else:
    plt.xticks(values, labels, rotation='vertical')
    g = sns.barplot(x=labels, y=values, color = col) 
    for p in g.patches:
        g.annotate(format(p.get_height(), '.0f'), (p.get_x() + p.get_width() / 2., 
                                                   p.get_height()), ha = 'center', 
                   va = 'center', xytext = (0, 5), textcoords = 'offset points')
        
plt.savefig(os.path.join(viz_path,'adjetivos_bigramas.jpg'))

# %%
# adj + sub
adj_sub = []
for text in df['respostas']:
    for p in punct:
        text = text.replace(p,'')
    tags = tagger.tag(word_tokenize(text))
    for i, tag in enumerate(tags):
        if tag[1]=='ADJ':
            if i-1 > 0 and tags[i-1][1] == 'N':
                adj_sub.append((tags[i-1][0], tag[0]))
            elif i+1 < len(tags) and tags[i-1][1] == 'N':
                adj_sub.append((tags[i+1][0], tag[0]))
                
count = Counter(adj_sub).most_common(15)
labels = []
values = []
for c in count:
    labels.append(c[0][0] + ' ' + c[0][1])
    values.append(c[1])
                
col = 'C0' 
orientation = 'vertical'
plt.title('Adjetivos + substantivos mais frequentes')

#
if orientation == 'vertical':
    g = sns.barplot(y=labels, x=values, color = col)
    for p in g.patches:
        g.annotate(format(p.get_width(), '.0f'), (p.get_width(), 
                                                   p.get_y() + p.get_height()/2.), ha = 'center', 
                   va = 'center', xytext = (10, 0), textcoords = 'offset points')
else:
    plt.xticks(values, labels, rotation='vertical')
    g = sns.barplot(x=labels, y=values, color = col) 
    for p in g.patches:
        g.annotate(format(p.get_height(), '.0f'), (p.get_x() + p.get_width() / 2., 
                                                   p.get_height()), ha = 'center', 
                   va = 'center', xytext = (0, 5), textcoords = 'offset points')
        
plt.savefig(os.path.join(viz_path,'adjetivos_substantivos.jpg'))

# %%
# verbos
verbs = ''
for text in df['respostas']:
    tags = tagger.tag(word_tokenize(text))
    for tag in tags:
        if tag[1]=='V':
            verbs += tag[0].lower() + ' '
# verbos mais frequentes
n_grams = (1,1)
total_bigrams = build_ngram_df(verbs, ngram = n_grams, n=20)
plt.title('Verbos mais frequentes')
plot_ngrams(total_bigrams, col='C7', orientation = 'vertical')
plt.savefig(os.path.join(viz_path,'verbos.jpg'))

# %%
import string
punct = string.punctuation
punct
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
# verb + sub
import string
punct = string.punctuation
verb_sub = []
for text in df['respostas']:
    for p in punct:
        text = text.replace(p,'')
    tags = tagger.tag(word_tokenize(text))
    for i, tag in enumerate(tags):
        if tag[1]=='V':
            if i-1 > 0 and tags[i-1][1] == 'N':
                verb_sub.append((tags[i-1][0], tag[0]))
            elif i+1 < len(tags) and tags[i-1][1] == 'N':
                verb_sub.append((tags[i+1][0], tag[0]))
                
count = Counter(verb_sub).most_common(15)
labels = []
values = []
for c in count:
    labels.append(c[0][0] + ' ' + c[0][1])
    values.append(c[1])
                
col = 'C9' 
orientation = 'vertical'
plt.title('Bigramas com verbos mais frequentes')

#
if orientation == 'vertical':
    g = sns.barplot(y=labels, x=values, color = col)
    for p in g.patches:
        g.annotate(format(p.get_width(), '.0f'), (p.get_width(), 
                                                   p.get_y() + p.get_height()/2.), ha = 'center', 
                   va = 'center', xytext = (10, 0), textcoords = 'offset points')
else:
    plt.xticks(values, labels, rotation='vertical')
    g = sns.barplot(x=labels, y=values, color = col) 
    for p in g.patches:
        g.annotate(format(p.get_height(), '.0f'), (p.get_x() + p.get_width() / 2., 
                                                   p.get_height()), ha = 'center', 
                   va = 'center', xytext = (0, 5), textcoords = 'offset points')
        
plt.savefig(os.path.join(viz_path,'verbos_bigramas.jpg'))

# %% [markdown]
# # Tamanho das entrevistas

# %%
brush = alt.selection(type='interval')
pts = alt.selection(type="interval", encodings=["x"])

rowbars = alt.Chart(df).mark_bar().encode(
    x='número de palavras:Q',
    y= alt.Y('título:O', sort = alt.EncodingSortField(field="número de palavras", order='descending')),   
    tooltip=['título', 'número de palavras', 'palavras-chave','respostas']
).transform_filter(
    brush
).transform_filter(
    pts
).properties(    
    height= 800,
    width = 300,
    title = 'Quantidade de palavras de cada entrevista'
)


hist_len = alt.Chart(df).mark_bar().encode(
    x = alt.X('número de palavras:Q', bin=alt.Bin(maxbins=30), title='Quantidade de palavras'),
    y = alt.Y('count()',title='Contagem'),
    tooltip = [alt.Tooltip('count():Q', title='Quantidade de entrevistas')]
    #color = alt.condition(pts, alt.value("darkgray"), alt.value("lightgray"))
).properties(
    width = 320,
    height = 200,
    title = 'Histograma da quantidade de palavras por entrevista'
).add_selection(pts)

hist_lex = alt.Chart(df).mark_bar().encode(
    x = alt.X("variabilidade léxica:Q", bin=alt.Bin(maxbins=30),title = 'variabilidade léxica'),
    y =alt.Y('count()',title='Contagem'),
    tooltip = [alt.Tooltip('count():Q', title='Contagem')],
).properties(    
    width = 320,
    height = 200,
    title = 'Histograma da variabilidade léxica'
).add_selection(pts)

hist_hap = alt.Chart(df).mark_bar().encode(
    x = alt.X("hapaxes:Q", bin=alt.Bin(maxbins=30),title = 'quantidade de hapaxes'),
    y =alt.Y('count()',title='Contagem'),
    tooltip = [alt.Tooltip('count():Q', title='Contagem')],
).properties(    
    width = 320,
    height = 200,
    title = 'Histograma de quantidade de hapaxes'
).add_selection(pts)

points = alt.Chart(df).mark_circle().encode(
    x='número de palavras:Q',
    y='variabilidade léxica:Q',
    tooltip=['título','número de palavras','variabilidade léxica','respostas'],
    size='hapaxes:Q'
).properties(    
    title = 'Número de palavras por variabilidade léxica'
).add_selection(
    brush
).transform_filter(
    pts
)

hconcat = alt.hconcat(
    rowbars,
    hist_len,
    hist_lex,
    hist_hap,
    points,
    data=df
)

hconcat = (rowbars | (hist_len & hist_lex & hist_hap) | points)

file = 'palavras_por_entrevista.html'
filepath = os.path.join(viz_path, file)
hconcat.save(filepath)
hconcat
# Out:
# alt.HConcatChart(...)

# %% [markdown]
# # Frequência das palavras

# %%
df_term.head(2)
# Out:
#     termo  frequencia  número de entrevistas onde o termo ocorre
# 3   gente         452                                          8  \
# 22    não         387                                          8
#
#                       entrevistas onde o termo ocorre
# 3   Canavieiras 1 Canavieiras 2 Cumbe 1 Cumbe 2 Ja...
# 22  Canavieiras 1 Canavieiras 2 Cumbe 1 Cumbe 2 Ja...

# %%
df_most_f = df_term.sort_values(by = 'frequencia', ascending = False)[0:50]
df_most_l = df_term.sort_values(by = 'número de entrevistas onde o termo ocorre', ascending = False)[0:50]


word_freq = alt.Chart(df_most_f).mark_bar().encode(
    x='frequencia:Q',
    y= alt.X('termo:O', sort = alt.EncodingSortField(field="frequencia", order='descending')),
    color = alt.value('steelblue'),
    tooltip=[
        'termo:O',
        'frequencia:Q',
        alt.Tooltip('entrevistas onde o termo ocorre:O', title='Entrevistas onde o termo ocorre')
    ]
).properties(    
    height=850,
    width = 300,
    title = 'Termos mais frequentes no total'
)

lyrics_count = alt.Chart(df_most_l).mark_bar().encode(
    x='número de entrevistas onde o termo ocorre:Q',
    y= alt.X('termo:O', 
                sort = alt.EncodingSortField(field="número de entrevistas onde o termo ocorre", order='descending')),
    color = alt.value('steelblue'),
    tooltip=[
        'termo:O',
        'número de entrevistas onde o termo ocorre:Q',
        alt.Tooltip('entrevistas onde o termo ocorre:O', title='Entrevistas onde o termo ocorre')
    ]
).properties(    
    height=850,
    width = 300,
    title = 'Termos que ocorrem em mais entrevistas'
)

hconcat = alt.hconcat(
    word_freq,
    lyrics_count,
)

hconcat = (word_freq | lyrics_count)

file = 'frequencia_dos_termos.html'
filepath = os.path.join(viz_path, file)
hconcat.save(filepath)
hconcat
# Out:
# alt.HConcatChart(...)

# %%
# hapaxes
hapaxes_df = df_term[df_term['frequencia']==1]
print('Total de hapaxes:', len(hapaxes_df))
for hapaxe, lyrics in zip(hapaxes_df['termo'], hapaxes_df['entrevistas onde o termo ocorre']):
    print(hapaxe + ': ' + lyrics)
# Out:
# Total de hapaxes: 1033
# isolar: Jardins 1
# catavam: Canavieiras 2
# achavam: Jardins 1
# ai…: Jardins 1
# entrega: Jardins 1
# adoecia: Jardins 1
# conviveu: Jardins 1
# comigo: Jardins 1
# perguntando: Canavieiras 2
# quando…: Jardins 1
# coiso: Jardins 1
# botasse: Jardins 1
# quero: Jardins 1
# pelo…: Jardins 1
# tensa: Canavieiras 2
# prometeram: Jardins 1
# convive: Jardins 1
# hoje…: Jardins 1
# dizer…: Jardins 1
# sintoma: Jardins 1
# crise…: Jardins 1
# rouquidão: Jardins 1
# somo…: Jardins 1
# cea…: Jardins 1
# saísse: Jardins 1
# pés: Jardins 1
# febre: Jardins 1
# aguentar: Jardins 1
# imaginar: Canavieiras 2
# sustentava: Canavieiras 2
# frio: Jardins 1
# nem…: Jardins 1
# perdi: Jardins 1
# paladar: Jardins 1
# vier: Jardins 1
# protegido: Jardins 1
# chão: Jardins 1
# diminuído: Jardins 1
# sentisse: Jardins 1
# almoçar: Jardins 1
# gaiatim: Jardins 1
# jardins…: Jardins 1
# tradicionais: Canavieiras 2
# dormir: Jardins 1
# morre: Jardins 1
# ganhou: Jardins 1
# ligeirim: Jardins 1
# sapato: Jardins 1
# vizinho: Jardins 1
# morro: Jardins 1
# mortalidade: Canavieiras 2
# hospício: Jardins 1
# pontal…: Jardins 1
# apreensivo: Canavieiras 2
# sofreram: Jardins 1
# precisar: Jardins 1
# comentários: Canavieiras 2
# ajuda…: Jardins 1
# achar: Jardins 1
# alimpar: Jardins 1
# esconderam: Jardins 1
# entrasse: Canavieiras 2
# toma: Jardins 1
# fraco: Jardins 1
# catastrófico: Canavieiras 2
# postos: Jardins 1
# qualquer: Jardins 1
# enfado: Jardins 1
# deitar: Jardins 1
# invadiu: Jardins 1
# saído: Jardins 1
# lembrava…: Jardins 1
# “quer: Jardins 1
# acabaram: Jardins 1
# comecei: Jardins 1
# acabado: Jardins 1
# vidas: Canavieiras 2
# esquecer: Jardins 1
# convivia: Jardins 1
# revolve: Jardins 1
# re…: Jardins 1
# matar: Jardins 1
# venci: Jardins 1
# puder: Jardins 1
# ameaçava: Jardins 1
# desses…um: Jardins 1
# cadastrar: Cumbe 1
# ninguém…: Jardins 1
# saio: Jardins 1
# derramam…: Cumbe 1
# concordo: Cumbe 1
# vende: Jardins 1
# aham: Cumbe 1
# marrai: Jardins 1
# mes: Jardins 1
# andar: Canavieiras 2
# campana: Canavieiras 2
# apoiasse: Jardins 1
# assalariado: Jardins 1
# fechamos: Canavieiras 2
# cuidou: Canavieiras 2
# doiss: Jardins 1
# vendiam: Jardins 1
# fatal: Canavieiras 2
# leves: Canavieiras 2
# as…as: Jardins 1
# trocava: Jardins 1
# por…: Jardins 1
# todim: Jardins 1
# micharia: Jardins 1
# guardar: Jardins 1
# morte: Canavieiras 2
# coisar: Jardins 1
# mercantil: Jardins 1
# “mamãe”: Jardins 1
# sentado: Jardins 1
# daquele: Jardins 1
# sofria”: Jardins 1
# creio: Canavieiras 2
# uhum: Cumbe 1
# querendo: Cumbe 2
# recuperando…: Jardins 1
# contemplada: Cumbe 2
# orientando: Cumbe 1
# veranistas: Cumbe 2
# acreditavam: Cumbe 2
# festas: Cumbe 2
# embate: Cumbe 2
# torto: Cumbe 2
# madrugada: Cumbe 2
# ameaças: Cumbe 2
# vigilância: Cumbe 2
# sanitárias: Cumbe 2
# confronto: Cumbe 2
# notícias: Cumbe 1
# esperança: Cumbe 1
# tempos: Cumbe 2
# devastação: Cumbe 1
# voltou: Cumbe 2
# doentes: Cumbe 2
# soubemos: Cumbe 2
# ficado: Cumbe 2
# estados: Cumbe 1
# feita: Cumbe 2
# confesso: Cumbe 1
# totalmente: Cumbe 1
# pedindo: Cumbe 2
# barrou: Cumbe 2
# causando: Cumbe 2
# observava: Cumbe 1
# prejudicar: Cumbe 2
# contemplando: Cumbe 2
# passassem: Canavieiras 2
# conter: Canavieiras 2
# sal: Jardins 1
# “mamãe…”: Jardins 1
# frente: Jardins 1
# esperava: Jardins 1
# consumiu: Jardins 1
# choque: Canavieiras 2
# frango: Jardins 1
# após: Canavieiras 2
# comer…”: Jardins 1
# ricão: Jardins 1
# sentir: Jardins 1
# sentiu: Jardins 1
# errada: Jardins 1
# casas: Jardins 1
# pneus: Jardins 1
# semanas: Jardins 1
# desastre: Canavieiras 2
# botada: Canavieiras 2
# bolacha: Jardins 1
# animais: Canavieiras 2
# suco: Jardins 1
# turma: Jardins 1
# morto: Canavieiras 2
# pista: Jardins 1
# peixes: Canavieiras 2
# perguntar: Jardins 1
# faziam: Jardins 1
# xiringavam: Jardins 1
# pneu: Jardins 1
# tragédia: Jardins 1
# deixava: Canavieiras 2
# barriga: Jardins 1
# empurrando: Jardins 1
# impactante: Canavieiras 2
# condição: Jardins 1
# mãmãe: Jardins 1
# “minha: Jardins 1
# pense: Jardins 1
# assim”: Jardins 1
# nascemo: Jardins 1
# aparecia: Jardins 1
# balada: Canavieiras 2
# alegre: Jardins 1
# dinheirinho: Jardins 1
# jovens: Canavieiras 2
# comprar…: Jardins 1
# tripa: Jardins 1
# consumindo: Jardins 1
# gravidade: Canavieiras 2
# passe: Jardins 1
# respiração: Jardins 1
# consciente: Canavieiras 2
# urgência: Canavieiras 2
# supermercado: Canavieiras 2
# adoeceu: Jardins 1
# desde: Jardins 1
# sofre: Jardins 1
# protegia: Canavieiras 2
# acostumado: Jardins 1
# esperando: Jardins 1
# falto: Canavieiras 2
# tosse: Canavieiras 2
# naquilo: Jardins 1
# pizza: Jardins 1
# abalou: Jardins 2
# otacília: Jardins 2
# misturada: Jardins 4
# recuperando: Jardins 4
# comparo: Jardins 4
# igualmente: Jardins 4
# violência: Jardins 4
# fragmento: Jardins 4
# local: Jardins 4
# proteção: Jardins 4
# sorte: Canavieiras 1
# aquisição: Jardins 4
# única: Jardins 4
# mobilizou: Jardins 4
# secretário: Jardins 4
# conversou: Jardins 4
# puxado: Jardins 4
# compartilhava: Canavieiras 1
# parar: Jardins 4
# amenizando: Canavieiras 1
# junho: Jardins 4
# março: Jardins 4
# abril: Jardins 4
# cpp: Canavieiras 1
# durava: Jardins 4
# aparecer: Jardins 4
# básicas: Jardins 4
# miudinha: Jardins 4
# obrigação: Jardins 4
# merenda: Jardins 4
# trás: Canavieiras 1
# aulas: Jardins 4
# arcar: Jardins 4
# merendas: Jardins 4
# paralisada: Jardins 4
# rotina: Jardins 4
# sustentar: Jardins 4
# materiais: Jardins 3
# evitar: Jardins 3
# viçosa: Jardins 3
# falou: Jardins 3
# fiscalização: Jardins 3
# entenderam: Jardins 3
# corpo: Jardins 3
# bombeiro: Jardins 3
# uniu: Jardins 3
# criou: Jardins 3
# ajuntando: Jardins 3
# respeitar: Jardins 3
# apoiando: Jardins 3
# acreditou: Jardins 3
# unindo: Jardins 3
# claro: Jardins 4
# contaminada: Jardins 4
# vendas: Jardins 4
# vendeu: Jardins 4
# peia: Jardins 4
# agosto: Jardins 4
# setembro: Jardins 4
# colocar: Canavieiras 1
# janeiro: Jardins 4
# tentativa: Jardins 4
# gastando: Jardins 4
# merreca: Jardins 4
# feiras: Jardins 4
# consumidor: Jardins 4
# apavorado: Jardins 4
# recebiam: Canavieiras 1
# informação: Jardins 4
# tenebroso: Jardins 4
# tido: Jardins 3
# sema: Jardins 4
# apelou: Jardins 4
# valer: Jardins 4
# benefício: Jardins 4
# cadastros: Jardins 4
# refazer: Jardins 4
# convidada: Jardins 4
# lembrei: Jardins 4
# coragem: Jardins 4
# lembrando: Jardins 4
# pera: Jardins 4
# pedido: Jardins 4
# acontecia: Jardins 4
# câmara: Jardins 4
# assembleia: Jardins 4
# rejeição: Canavieiras 1
# conscientizar: Jardins 4
# mostrar: Jardins 4
# alcance: Jardins 4
# entendia: Jardins 4
# entendessem: Jardins 4
# entenderem: Jardins 4
# recebi: Jardins 4
# reclama: Jardins 4
# impossibilitada: Canavieiras 1
# cruel: Jardins 4
# consegue: Jardins 4
# dessas: Jardins 4
# matéria: Jardins 4
# higiene: Jardins 4
# jesus: Jardins 4
# cristo: Jardins 4
# conversa: Jardins 4
# voltava: Canavieiras 1
# governador: Jardins 4
# barco: Jardins 4
# velha: Jardins 4
# baixo: Jardins 4
# pensava: Canavieiras 1
# passado: Jardins 4
# coloquei: Canavieiras 1
# internos: Jardins 4
# sequela: Jardins 4
# perda: Jardins 4
# filha: Jardins 4
# sarar: Jardins 4
# obrigada: Canavieiras 1
# suficiência: Jardins 4
# braço: Jardins 4
# perna: Jardins 4
# equilibrar: Jardins 4
# audiência: Jardins 4
# consultei: Jardins 4
# medico: Jardins 4
# barulho: Jardins 4
# vontade: Jardins 4
# explicar: Jardins 4
# complicado: Jardins 4
# sinto: Jardins 4
# aperreada: Jardins 4
# paguei: Jardins 4
# mantendo: Jardins 4
# piorar: Jardins 4
# tamanho: Jardins 4
# ovo: Jardins 4
# apelar: Jardins 4
# acontecido: Jardins 3
# formar: Jardins 3
# albuquerque: Jardins 2
# naquela: Jardins 2
# continua: Canavieiras 1
# decisão: Jardins 2
# visitar: Jardins 2
# finais: Jardins 2
# lutando: Canavieiras 1
# fiocruz: Jardins 2
# moradores: Jardins 2
# comparecer: Canavieiras 1
# desenvolvendo: Canavieiras 1
# pegado: Jardins 2
# jardins: Jardins 2
# punido: Canavieiras 1
# assistido: Canavieiras 1
# gravíssima: Canavieiras 1
# continuado: Jardins 2
# público: Canavieiras 1
# proibindo: Jardins 2
# proíbe: Jardins 2
# caminho: Jardins 2
# entrarem: Jardins 2
# acabam: Jardins 2
# viram: Jardins 2
# pegando: Jardins 2
# besteira: Jardins 2
# revezamento: Jardins 2
# brincadeira: Jardins 2
# reclamar: Jardins 2
# aceitar: Jardins 2
# regra: Jardins 2
# dificuldades: Canavieiras 1
# tarde: Jardins 3
# 500: Jardins 2
# série: Jardins 2
# tirou: Jardins 2
# achasse: Jardins 2
# gravação: Jardins 2
# impactado: Jardins 2
# maneira: Jardins 2
# atravessadores: Jardins 2
# poluindo: Jardins 2
# físico: Jardins 2
# sensação: Jardins 2
# desconhecida: Canavieiras 2
# ruim: Canavieiras 2
# poluído: Jardins 2
# termo: Jardins 2
# banda: Jardins 2
# falaram: Canavieiras 1
# negado: Canavieiras 1
# cuidar: Jardins 2
# liberaram: Jardins 2
# depressiva: Jardins 2
# usando: Jardins 2
# reconhecido: Canavieiras 1
# horas: Jardins 2
# lagoas: Cumbe 2
# pavor: Jardins 2
# enquanto: Canavieiras 1
# seis: Jardins 2
# testes: Jardins 2
# cantos: Jardins 2
# lavar: Jardins 2
# assistência: Canavieiras 1
# restaurantes: Jardins 2
# vivia: Canavieiras 1
# supor: Jardins 3
# diminuir: Jardins 3
# janta: Jardins 3
# guardado: Jardins 3
# produtos: Jardins 3
# comprador: Jardins 3
# aparecendo: Jardins 3
# freezer: Jardins 3
# estragar: Jardins 3
# frezzer: Jardins 3
# guardava: Jardins 3
# quis: Canavieiras 1
# isolado: Jardins 3
# aonde: Jardins 3
# abalo: Jardins 3
# parada: Jardins 3
# analises: Jardins 3
# tristeza: Canavieiras 1
# remédio: Jardins 3
# esquece: Canavieiras 1
# 09h00: Jardins 3
# 07h00: Jardins 3
# nove: Jardins 3
# 08h30: Jardins 3
# misturando: Jardins 3
# descarregar: Jardins 3
# mercadoria: Jardins 3
# idosos: Jardins 3
# dica: Jardins 3
# prevenida: Jardins 3
# alertar: Jardins 3
# maninha: Jardins 3
# ajuntou: Jardins 3
# unida: Jardins 3
# inteirava: Jardins 3
# paradinha: Jardins 3
# sofrimento: Jardins 3
# superar: Jardins 3
# atingia: Jardins 3
# assistindo: Canavieiras 1
# pescaria: Jardins 3
# peesco: Jardins 3
# abrisse: Jardins 3
# comprovar: Jardins 3
# triste: Jardins 3
# mentia: Jardins 3
# atingida: Jardins 3
# debilitado: Canavieiras 1
# repente: Jardins 3
# orientar: Jardins 3
# topasse: Jardins 3
# líquido: Jardins 3
# luz: Jardins 3
# carente: Canavieiras 1
# criemo: Jardins 3
# raiz: Jardins 3
# olho: Jardins 3
# perdeu: Canavieiras 1
# chocou: Jardins 3
# amizades: Canavieiras 1
# sofrer: Jardins 3
# parou: Jardins 3
# cidades: Jardins 3
# contar: Canavieiras 1
# espalhando: Jardins 3
# ouviu: Jardins 3
# transportador: Jardins 3
# ruína: Jardins 3
# nascemos: Jardins 3
# estarem: Cumbe 2
# participou: Cumbe 2
# comun…: Cumbe 1
# importa: Cumbe 1
# aprendi: Cumbe 1
# rápido: Cumbe 1
# nomezinho: Cumbe 1
# sereste…: Cumbe 1
# estabilidade: Cumbe 1
# organizavam: Cumbe 1
# muito…: Cumbe 1
# professora: Cumbe 1
# fortaleza…: Cumbe 1
# deveres: Cumbe 1
# alertando: Cumbe 1
# problemático: Cumbe 1
# reinventando: Cumbe 1
# seu…: Cumbe 1
# mior: Cumbe 1
# esqueci: Cumbe 1
# ignora: Cumbe 1
# governamental: Cumbe 1
# orgãos: Cumbe 1
# vi…: Cumbe 1
# socorrer: Cumbe 1
# assusta: Cumbe 1
# dão: Cumbe 1
# abraçado: Cumbe 1
# degradação: Cumbe 1
# alegam…: Cumbe 1
# poluição: Cumbe 1
# diminuição: Cumbe 1
# fragilidade: Cumbe 1
# empreendimento: Cumbe 1
# adaptando: Cumbe 1
# começar: Cumbe 1
# articulação: Cumbe 1
# provocado: Cumbe 1
# dada: Cumbe 1
# demo: Cumbe 1
# vivenciemo: Cumbe 1
# mentira: Cumbe 1
# parecia: Cumbe 1
# vinhemo: Cumbe 1
# deparemo: Cumbe 1
# tradicional: Cumbe 1
# parceria…: Cumbe 1
# acionava: Cumbe 1
# oia: Cumbe 1
# aprendemos: Cumbe 1
# mexer: Cumbe 1
# online: Cumbe 1
# comunicar: Cumbe 1
# aula: Cumbe 1
# importante: Cumbe 1
# interagir: Cumbe 1
# ignorar: Cumbe 1
# céu: Cumbe 1
# tudo…: Cumbe 1
# reivindicava: Cumbe 1
# criança: Cumbe 1
# escolar: Cumbe 1
# meno: Cumbe 1
# forma…: Cumbe 1
# gps: Cumbe 1
# orgão: Cumbe 1
# plataforma: Cumbe 1
# vinheram: Cumbe 1
# louco: Cumbe 1
# desmonte: Cumbe 1
# criando: Cumbe 1
# arrepiando: Cumbe 1
# são…: Cumbe 1
# poucas: Cumbe 1
# encontrando: Cumbe 1
# situação…: Cumbe 1
# acompanhado: Cumbe 1
# município: Cumbe 1
# chegue: Cumbe 1
# psicológica: Cumbe 1
# litro: Cumbe 1
# recurso…: Cumbe 1
# cursozinho: Cumbe 1
# corte: Cumbe 1
# costura: Cumbe 1
# dar…: Cumbe 1
# to…: Cumbe 1
# negociando: Cumbe 1
# carga: Cumbe 1
# doam: Cumbe 1
# entrou…: Cumbe 1
# sensíveis: Cumbe 1
# área: Cumbe 1
# disseram…: Cumbe 1
# fizeram…: Cumbe 1
# fizesse: Cumbe 1
# manguezais: Cumbe 1
# mostrasse: Cumbe 1
# colocasse: Cumbe 1
# distribuísse: Cumbe 1
# lutou: Cumbe 1
# então…: Cumbe 1
# acompanhada: Cumbe 1
# organizaram: Cumbe 1
# familias: Cumbe 1
# únicas: Cumbe 1
# trouxe: Cumbe 1
# encontra: Cumbe 1
# desassistência: Cumbe 1
# fato: Cumbe 1
# bateram: Cumbe 1
# farmácia: Cumbe 1
# fotos: Cumbe 1
# quem…: Cumbe 1
# necessária: Cumbe 1
# enfermeiro: Cumbe 1
# firmado: Cumbe 1
# dificultoso: Cumbe 1
# comprasse: Cumbe 1
# estranho: Cumbe 1
# tirar…: Cumbe 1
# dissemo: Cumbe 1
# prum…: Cumbe 1
# sensibilizou: Cumbe 1
# disso”: Cumbe 1
# acessível: Cumbe 1
# inseguro: Cumbe 1
# cento: Cumbe 1
# cem: Cumbe 1
# vazar: Cumbe 1
# umas…: Cumbe 1
# pressionada: Cumbe 1
# movimentação: Cumbe 1
# meia…: Cumbe 1
# sossegado: Cumbe 1
# organização: Cumbe 1
# todinha: Cumbe 1
# vêm: Cumbe 1
# quarenta: Cumbe 1
# expulsassivo: Cumbe 1
# acontecece: Cumbe 1
# camarão: Cumbe 1
# arrastar: Cumbe 1
# estruturado: Cumbe 1
# atravessador: Cumbe 1
# entregava: Cumbe 1
# aumento…: Cumbe 1
# fazem: Cumbe 1
# economia: Cumbe 1
# aumentou: Cumbe 1
# cata: Cumbe 1
# porte: Cumbe 1
# saia: Cumbe 1
# maridos: Cumbe 1
# problemática: Cumbe 1
# vivenciei: Cumbe 1
# vivi…: Cumbe 1
# inseguranças: Cumbe 1
# futuro: Cumbe 1
# alcancei: Cumbe 1
# insônia: Cumbe 1
# dormia: Cumbe 1
# você…: Cumbe 1
# envolvimento: Cumbe 1
# afetamento: Cumbe 1
# esposa: Cumbe 1
# nessa…: Cumbe 1
# ato: Cumbe 1
# político: Cumbe 1
# desempreendimento: Cumbe 1
# pitu: Cumbe 1
# garantiu: Cumbe 1
# propriedade: Cumbe 1
# reconheceu: Cumbe 1
# tenho…: Cumbe 1
# esses…: Cumbe 1
# aceitemo: Cumbe 1
# cadastremo: Cumbe 1
# entregasse: Cumbe 1
# regularizada: Cumbe 1
# documentação: Cumbe 1
# bateu: Cumbe 1
# xerox: Cumbe 1
# fichas: Cumbe 1
# nasceram: Cumbe 1
# entregamo: Cumbe 1
# reconheciam: Cumbe 1
# prioridade…: Cumbe 1
# patriarcal: Cumbe 1
# menos…: Cumbe 1
# dito…: Cumbe 1
# predominação: Cumbe 1
# pros…: Cumbe 1
# homen: Cumbe 1
# desamparo: Cumbe 1
# presidente: Cumbe 1
# direitos: Cumbe 1
# fartura: Cumbe 1
# pagamos: Cumbe 1
# cabou: Cumbe 1
# pergunta: Cumbe 1
# carcinicultura: Cumbe 1
# esgoto: Cumbe 1
# guardiões: Cumbe 1
# palavra: Cumbe 1
# trabalha…: Cumbe 1
# adoecesse: Cumbe 1
# medida: Cumbe 1
# desonesta: Cumbe 1
# falava: Cumbe 1
# adoecido: Cumbe 1
# pobre…: Cumbe 1
# terra: Cumbe 1
# plantar: Cumbe 1
# direito…: Cumbe 1
# marginalizam: Cumbe 1
# organiza: Cumbe 1
# reinvidica: Cumbe 1
# dará: Cumbe 1
# tratado: Cumbe 1
# imaginando: Cumbe 1
# básico: Cumbe 1
# sobrecarregado: Cumbe 1
# ficar…: Cumbe 1
# acolhido: Cumbe 1
# perde: Cumbe 1
# passear: Cumbe 1
# comecemo: Cumbe 1
# educar: Cumbe 1
# necessário: Cumbe 1
# sentimento: Cumbe 1
# passemo: Cumbe 1
# olhe: Cumbe 1
# acreditar: Cumbe 1
# consequência: Cumbe 1
# temo: Cumbe 1
# conseguimos: Cumbe 1
# perseguida: Cumbe 1
# marginalizada: Cumbe 1
# interpreta: Cumbe 1
# visibilidade: Cumbe 1
# um…é: Cumbe 1
# preocupam: Cumbe 1
# cuida: Cumbe 1
# deve…: Cumbe 1
# contra…: Cumbe 1
# sente: Cumbe 1
# exemplo…: Cumbe 1
# organizou: Cumbe 1
# resguardar: Cumbe 1
# elas…: Cumbe 1
# vivência: Cumbe 1
# acolhimento: Cumbe 1
# majorlândia: Cumbe 1
# impacta: Cumbe 1
# inverno: Cumbe 1
# retrato: Cumbe 1
# pouca: Cumbe 1
# pouquíssimos: Cumbe 1
# bebedeira: Cumbe 1
# muita…: Cumbe 1
# descontrolada: Cumbe 1
# estamo: Cumbe 1
# marido: Cumbe 1
# exige: Cumbe 1
# organizamo: Cumbe 1
# recebendo…: Cumbe 1
# estruturando: Cumbe 1
# possível: Cumbe 1
# vária: Cumbe 1
# base: Cumbe 1
# dificuldade…: Cumbe 1
# inadmissível: Cumbe 1
# vacinava: Cumbe 1
# grandes: Cumbe 1
# olha…: Cumbe 1
# mandado: Cumbe 1
# enfermeira: Cumbe 1
# vai…: Cumbe 1
# variar: Cumbe 1
# médicos: Cumbe 1
# recebido: Cumbe 1
# substância: Cumbe 1
# orientava: Cumbe 1
# irritada: Cumbe 1
# vacinar: Cumbe 1
# motivo: Cumbe 1
# colocaram: Cumbe 1
# sufoco: Cumbe 1
# vacinação: Cumbe 1
# medonho: Cumbe 1
# conseguimo: Cumbe 1
# organizativo…: Cumbe 1
# ficando: Cumbe 1
# adoecendo: Cumbe 1
# diário: Cumbe 1
# terem: Cumbe 1
# condução: Cumbe 1
# conduzirem: Cumbe 1
# vestígios: Cumbe 2
# pai: Cumbe 1
# antepassado: Cumbe 1
# risco: Cumbe 2
# dinâmica: Cumbe 1
# males: Cumbe 1
# concederam: Cumbe 1
# estudantes: Cumbe 1
# epis: Cumbe 1
# nome…: Cumbe 1
# fins: Cumbe 1
# irritou: Cumbe 1
# o…foi: Cumbe 1
# pro…: Cumbe 1
# define: Cumbe 1
# banhista: Cumbe 1
# termina: Cumbe 1
# certificação: Cumbe 1
# identidade…: Cumbe 1
# aprovado: Cumbe 1
# recife: Cumbe 1
# dado: Cumbe 1
# coisas”: Cumbe 1
# enfermeira…: Cumbe 1
# união: Cumbe 1
# “gente: Cumbe 1
# equipamentos: Cumbe 1
# tento: Cumbe 1
# cadeira: Cumbe 1
# ventilado: Cumbe 1
# confortável: Cumbe 1
# defende: Cumbe 1
# mensagem: Cumbe 1
# mandava…: Cumbe 1
# conversando: Cumbe 1
# próprias: Cumbe 1
# enfermeiras: Cumbe 1
# dialogar: Cumbe 1
# defensoria: Cumbe 1
# dinâmico: Cumbe 1
# periódico: Cumbe 1
# periódicas: Cumbe 1
# projetos: Cumbe 2
# trabalhamo: Cumbe 1
# povos: Cumbe 2
# nova: Cumbe 2
# ligado: Cumbe 2
# depara: Cumbe 1
# fechar: Cumbe 2
# novamente: Cumbe 2
# passam: Cumbe 2
# prejudicou: Cumbe 2
# ideia: Cumbe 1
# parado: Cumbe 2
# contamos: Cumbe 2
# como…: Cumbe 1
# doaram: Cumbe 2
# doamos: Cumbe 2
# pescas: Cumbe 1
# comprovadamente: Cumbe 2
# dissesse: Cumbe 2
# falecer: Cumbe 2
# pulmão: Cumbe 2
# comprometido: Cumbe 2
# balão: Cumbe 2
# oxigênio: Cumbe 2
# familiar: Cumbe 2
# parente: Cumbe 2
# mexia: Cumbe 2
# lockdown: Cumbe 2
# podiam: Cumbe 2
# acham: Cumbe 2
# indicando: Cumbe 1
# denunciar: Cumbe 2
# procurar: Cumbe 2
# defenderam: Cumbe 1
# avisar: Cumbe 2
# vigilha: Cumbe 1
# provavelmente: Cumbe 2
# vigi…: Cumbe 1
# buzio: Cumbe 2
# perder: Cumbe 1
# tirando: Cumbe 2
# pagar: Cumbe 2
# seguro: Cumbe 2
# identidade: Cumbe 1
# extrai: Cumbe 1
# completamente: Cumbe 2
# afetado: Cumbe 1
# criminosa: Cumbe 2
# pensar: Cumbe 2
# entregue: Cumbe 2
# abrangeu: Cumbe 2
# continuou: Cumbe 2
# catadores: Cumbe 2
# resume: Cumbe 1
# mortandade: Cumbe 2
# inexistência: Cumbe 2
# pescando: Cumbe 2
# mobilizando: Cumbe 2
# geralmente: Cumbe 1
# cometido: Cumbe 2
# crime: Cumbe 2
# postar: Cumbe 2
# vigiando: Cumbe 2
# demos: Cumbe 2
# prestaram: Cumbe 1
# deles…: Cumbe 1
# foro: Cumbe 1
# anotado: Cumbe 1
# sei…: Cumbe 1
# lembrada: Cumbe 1
# significado: Cumbe 1
# oceania: Cumbe 1
# capacitada: Cumbe 1
# comu…: Cumbe 1
# cdph: Cumbe 1
# doações: Cumbe 1
# orientada: Cumbe 1
# aspecto: Cumbe 1
# tentasse: Cumbe 1
# socorreu: Cumbe 1
# usasse: Cumbe 1
# comprado: Cumbe 1
# indicação: Cumbe 1
# prioritário: Cumbe 1
# conquistou: Cumbe 1
# suspeita: Cumbe 1
# aumento: Cumbe 1
# ameaçado: Cumbe 1
# chikungunya: Cumbe 1
# dengue: Cumbe 1
# formação: Cumbe 1
# infinita: Cumbe 1
# aparato: Cumbe 1
# gravíssimo: Cumbe 1
# racismo: Cumbe 1
# institucional: Cumbe 1
# entraria: Cumbe 1
# prioridade: Cumbe 1
# visitou: Cumbe 1
# encontrado: Cumbe 1
# palmares: Cumbe 1
# cultural: Cumbe 1
# cruzado: Cumbe 1
# onde…: Cumbe 1
# conhece: Cumbe 1
# questão…: Cumbe 1
# projetos…: Cumbe 1
# braços: Cumbe 1
# cum…: Cumbe 1
# entidades…: Cumbe 1
# aceito: Cumbe 1
# tava…: Cumbe 1
# esperar: Cumbe 1
# fizemo…: Cumbe 1
# trágica: Cumbe 1
# ganhar: Cumbe 1
# canavieira: Cumbe 1
# invasão: Cumbe 1
# questionou: Cumbe 1
# icapuí: Cumbe 1
# audiências: Cumbe 1
# pedra: Cumbe 1
# galo: Cumbe 1
# direitinho: Cumbe 1
# aceito…: Cumbe 1
# riquíssimo: Cumbe 1
# depararam: Cumbe 1
# desestrutura: Cumbe 1
# visita: Cumbe 1
# própria…: Cumbe 1
# fundação: Cumbe 1
# informações: Cumbe 1
# entramo: Cumbe 1
# lista: Cumbe 1
# brigaram: Cumbe 1
# fui…: Cumbe 1
# botei: Cumbe 1
# garis: Cumbe 1
# partido: Cumbe 1
# preto: Cumbe 1
# entravam: Cumbe 1
# “valha: Cumbe 1
# comadre: Cumbe 1
# informado: Cumbe 1
# “mulher: Cumbe 1
# simbólica: Cumbe 1
# adoeceram: Cumbe 1
# morreram: Cumbe 1
# coletivo: Cumbe 1
# ouvi: Cumbe 1
# seguida: Cumbe 1
# tira: Cumbe 1
# privado: Cumbe 1
# diziam: Cumbe 1
# faleceu: Cumbe 1
# desespero: Cumbe 1
# vídeo: Cumbe 1
# conhecia: Cumbe 1
# nosso…: Cumbe 1
# sube…: Cumbe 1
# aumenta: Cumbe 1
# equipamento: Cumbe 1
# judicial: Cumbe 1
# vestígio: Cumbe 1
# usou: Cumbe 1
# louca: Cumbe 1
# sujeira: Cumbe 1
# escondida: Cumbe 1
# lidando: Cumbe 1
# tomaria: Cumbe 1
# conquista: Cumbe 1
# postando: Cumbe 1
# últimas: Cumbe 1
# próprio: Cumbe 1
# reconhecimento: Cumbe 1
# agiu: Cumbe 1
# impressionada: Cumbe 1
# do…como: Cumbe 1
# procurou: Cumbe 1
# dos…: Cumbe 1
# to…”: Cumbe 1
# assustador: Cumbe 1
# já…e: Cumbe 1
# super: Cumbe 1
# limpo: Cumbe 1
# vem…: Cumbe 1
# negando: Cumbe 1
# começo…: Cumbe 1
# fake: Cumbe 1
# news: Cumbe 1
# rolou: Cumbe 1
# limpava: Cumbe 1
# tomasse: Cumbe 1
# morra: Cumbe 1
# adoeça: Cumbe 1
# coisa…: Cumbe 1
# divulgado: Cumbe 1
# proximo: Cumbe 1
# agradou: Jardins 4

# %% [markdown]
# # Matriz de similaridade

# %%
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(list(df['resposta normalizada']))
cosine_sim = cosine_similarity(X,X)
df_similar = pd.DataFrame(cosine_sim, columns = df['título'], index = df['título'])
df_similar['título'] = df['título']

source = df_similar.melt(id_vars=['título'])
source.columns = ['entrevista i', 'entrevista j', 'similaridade']
source['entrevista j'] = list(df['título'])*len(df['título'])
source.head()
# Out:
#     entrevista i   entrevista j  similaridade
# 0  Canavieiras 1  Canavieiras 1      1.000000
# 1  Canavieiras 1  Canavieiras 2      0.541840
# 2  Canavieiras 1        Cumbe 1      0.500030
# 3  Canavieiras 1        Cumbe 2      0.558698
# 4  Canavieiras 1      Jardins 1      0.521453

# %%
alt.data_transformers.disable_max_rows()
matrix_sim = alt.Chart(source).mark_rect().encode(
    x='entrevista i:O',
    y='entrevista j:O',
    color=alt.Color('similaridade:Q', scale=alt.Scale(scheme="inferno")),
    tooltip=[
        alt.Tooltip('entrevista i:O', title='i'),
        alt.Tooltip('entrevista j:O', title='j'),
        alt.Tooltip('similaridade:Q', title='Similaridade'),
    ]
).properties(    
    width = 500,
    height= 500,    
    title = 'Matriz de similaridade entre entrevistas'
)

file = 'similaridade.html'
filepath = os.path.join(viz_path, file)
matrix_sim.save(filepath)
matrix_sim
# Out:
# alt.Chart(...)

# %% [markdown]
# # Grafo de co-ocorrência

# %%
bigrams = build_ngram_df(df['resposta normalizada'], ngram = (2,2), n=None,)
max_range = 200

ngrams = [(t.split()[0],t.split()[1]) for t in bigrams.index[0:max_range]]
values = [int(i) for i in bigrams.values[0:max_range]]
d = dict(zip(ngrams,values))

net = Network(width = '1250', height = '800px',notebook = True, directed=True)
# Create connections between nodes
for k in d:
    #print(k[0] + "," + k[1] + str(d[k]))
    net.add_node(k[0], label = k[0], value = d[k])
    net.add_node(k[1], label = k[1], value = d[k])
    net.add_edge(k[0], k[1], weight = d[k])

#net.show_buttons(filter_=['physics'])
file = 'network.html'
filepath = os.path.join(viz_path, file)
net.save_graph(file)
print('saved')
net.show(file)
# Out:
# Warning: When  cdn_resources is 'local' jupyter notebook has issues displaying graphics on chrome/safari. Use cdn_resources='in_line' or cdn_resources='remote' if you have issues viewing graphics in a notebook.
# saved
# network.html
#         <iframe
#             width="1250"
#             height="800px"
#             src="network.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# # Análise de sentimentos

# %%
from libretranslatepy import LibreTranslateAPI
import time
lt = LibreTranslateAPI("https://translate.argosopentech.com/")
#if 'tradução' not in df.columns:
translated_aswers = []
for interviewee in list(df['respostas']):
    translated = []
    for line in interviewee.split('\n'):
        if len(line)>0:
            line_trans = lt.translate(line, "pt", "en")
            #print(line_trans)
            translated.append(line_trans)
            time.sleep(0.5)
            print()
    translated = '\n'.join(translated)
    translated_aswers.append(translated)

df['tradução'] = translated_aswers
df.to_csv(os.path.join(module_path, 'data', 'entrevistas.csv'),index=False)

# %%
def classify_sentiment(pol):
    if pol >= 0.1:
        return 'Positivo'
    elif pol >= -0.1:
        return 'Neutro'
    else:
        return 'Negativo'
    
titles = []
lines = []   
polarities = []
subjectivities = []
for text, title in zip(df['tradução'],df['título']):
    for line in text.split('\n'):
        if len(line) > 0:
            blob = TextBlob(line)
            polarities.append(blob.sentiment.polarity) 
            subjectivities.append(blob.sentiment.subjectivity)
            titles.append(title)
            lines.append(line)

sent = [classify_sentiment(x) for x in polarities]
n_words = [len(x.split(' ')) for x in lines]
df_sent = pd.DataFrame({'sentimento':sent, 'polaridade':polarities, 'subjetividade':subjectivities,
                       'número de palavras':n_words, 'título':titles, 'respostas': lines})

# %%
df_sent
# Out:
#     sentimento  polaridade  subjetividade  número de palavras         título
# 0     Negativo   -0.101948       0.570779                 104  Canavieiras 1  \
# 1     Positivo    0.225000       0.266667                  10  Canavieiras 1
# 2       Neutro    0.000000       0.125000                   3  Canavieiras 1
# 3       Neutro    0.040000       0.260000                  39  Canavieiras 1
# 4     Positivo    0.142857       0.267857                   4  Canavieiras 1
# ..         ...         ...            ...                 ...            ...
# 218     Neutro    0.031548       0.511756                 104      Jardins 4
# 219   Positivo    0.470899       0.553862                 100      Jardins 4
# 220     Neutro   -0.005000       0.512500                 111      Jardins 4
# 221     Neutro    0.000000       0.000000                   2      Jardins 4
# 222   Positivo    0.500000       1.000000                   7      Jardins 4
#
#                                              respostas
# 0    so it was. It's impacted a lot, right? Because...
# 1     it wasn't as much as the first, but it impacted.
# 2                                 this same insecurity
# 3    not so much physics, but the mental yes. a lot...
# 4                                  I'll be right back.
# ..                                                 ...
# 218  No, it was the sema, we were invited to attend...
# 219  the challenge we had was to raise awareness of...
# 220  I can't even tell you if I got any results fro...
# 221                                         That's it.
# 222        He knows that neither jesus Christ pleased.
#
# [223 rows x 6 columns]

# %%
# visualização interativa

brush = alt.selection(type='interval')

pts = alt.selection(type="interval", encodings=["x"])

points = alt.Chart(df_sent).mark_circle().encode(
    x='polaridade:Q',
    y='subjetividade:Q',
    color=alt.condition(brush, 'sentimento:N', alt.value('lightgray')),
    tooltip=['título','polaridade','subjetividade','respostas'],
    size='número de palavras:Q'
).properties(    
    title = 'Polaridade x Subjetividade'
).add_selection(
    brush
).transform_filter(
    pts
)

bars = alt.Chart(df_sent).mark_bar().encode(
    y=alt.Y('sentimento:N', title = 'Categorias de polaridade'),
    color='sentimento:N',
    x=alt.X('count(sentimento):Q', title = 'Contagem'),
    tooltip = [alt.Tooltip('count():Q', title='Contagem')],
).properties(    
    title = 'Categorias de Polaridade'
).transform_filter(
    brush
).transform_filter(
    pts
)

hist_pol = alt.Chart(df_sent).mark_bar().encode(
    x = alt.X("polaridade:Q", bin=alt.Bin(maxbins=30),title = 'polaridade'),
    y =alt.Y('count()',title='Contagem'),
    tooltip = [alt.Tooltip('count():Q', title='Contagem')],
    color = alt.condition(pts, 'sentimento:N', alt.value("lightgray"))
).properties(    
    width = 320,
    height = 200,
    title = 'Histograma da polaridade'
).add_selection(pts)


hist_sub = alt.Chart(df_sent).mark_bar().encode(
    x = alt.X("subjetividade:Q", bin=alt.Bin(maxbins=30),title = 'subjetividade'),
    y =alt.Y('count()',title = 'Contagem'),
    tooltip = [alt.Tooltip('count():Q', title='Contagem')],
    color = alt.condition(pts, alt.value("lightblue"), alt.value("lightgray"))
).properties(    
    width = 320,
    height = 200,
    title = 'Histograma da subjetividade'
).add_selection(pts)

sent = alt.hconcat(
    points & bars,
    hist_pol & hist_sub,
    data=df
)

pol = alt.Chart(df_sent).mark_bar().encode(
    y="polaridade:Q",
    x= alt.X("título:O", sort = alt.EncodingSortField(field="polaridade", order='descending')),
    tooltip = ['título','polaridade','respostas'],
    color= 'sentimento'
).properties(
    width=800,
    height = 300,
    title = 'Polaridade das entrevistas'
).transform_filter(
    pts
)

sent = ((points & bars) | (hist_sub & hist_pol)) & pol
sent.properties(title = 'Análise de Sentimentos')
file = 'analise_sentimentos.html'
filepath = os.path.join(viz_path, file)
sent.save(filepath)
sent
# Out:
# alt.VConcatChart(...)
